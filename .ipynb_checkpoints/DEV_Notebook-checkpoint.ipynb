# %%
# %load_ext autoreload
# %config Completer.use_jedi = False
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2
import FEMOL
import numpy as np
np.set_printoptions(linewidth=200)
np.set_printoptions(suppress=True)
from IPython.display import clear_output
import matplotlib.pyplot as plt
from scipy.interpolate import interp1d, griddata, interp2d, RectBivariateSpline
import time
import runpy
import os
import sys
import pandas as pd

# %% [markdown]
# # Development Notebook for the FEMOL Project

# %%
def analyse_mesh(meshfile, eigvalfile, mode):
    # Load the data
    mesh = FEMOL.mesh.load_vtk(meshfile)
    eigvals = np.load(eigvalfile)
    # Plot the moda of vibration
    fig, ax = plt.subplots()
    plt.sca(ax)
    mesh.plot.point_data('m1_Uz')
    ax.set_title(f'Mode of vibration {mode}')
    # Plot the optimization results
    fig, axs = plt.subplots(5,4, figsize=(16, 20))
    for key, eig, ax in zip(mesh.cell_data.keys(), eigvals, axs.flatten()):
        plt.sca(ax)
        mesh.cell_to_point_data(key)
        mesh.plot.point_data(key, cmap='Greys')
        FEMOL.utils.guitar_outline2(L=1)
        title = f'TOM results {key} eigfreq {int(np.round(eig))} Hz'
        ax.set_title(title)

# %%
analyse_mesh('Results/_topopt_cache/TOM_2022-03-28_04_35_41.vtk', 
             'eigen_values_lcar03_T11_2022-03-28_07_57_18.npy', 'T11')

# %%
analyse_mesh('Results/_topopt_cache/TOM_2022-03-28_04_36_07.vtk', 
             'eigen_values_lcar03_T21_2022-03-28_07_58_11.npy', 'T21')

# %%
analyse_mesh('Results/_topopt_cache/TOM_2022-03-28_04_36_26.vtk', 
             'eigen_values_lcar03_T12_2022-03-28_07_58_30.npy', 'T12')

# %%
analyse_mesh('Results/_topopt_cache/TOM_2022-03-28_04_36_45.vtk', 
             'eigen_values_lcar03_T31_2022-03-28_07_58_47.npy', 'T31')

# %%
analyse_mesh('Results/_topopt_cache/TOM_2022-03-28_00_27_05.vtk', 
             'Results/_topopt_cache/eigvals_2022-03-28_00_27_05.npy', 'T11')

# %%
_ = runpy.run_path('guitar_lcar05_T11.py')
# Out:
# solving SIMP problem for mode T11 2022-03-28_09_23_09
# Solving using scipy.linalg.eigh(K, M)
# solved in 3.247661828994751 s
# Best mac match (fast solver) : 0.9774030452459805
# Iteration : 1, Variation : 0.30000000000000004, EigenVal : 159.1840546762715
# Best mac match (fast solver) : 0.40420717067744755
# Iteration : 2, Variation : 0.30000000000000004, EigenVal : 160.64726646339275
# Best mac match (fast solver) : 0.4261685441753897
# Iteration : 3, Variation : 0.29999999999999993, EigenVal : 165.05841614437125
# Best mac match (fast solver) : 0.44296949688262144
# Iteration : 4, Variation : 0.16228751944481234, EigenVal : 167.17608549514853
# Best mac match (fast solver) : 0.45180874473290217
# Iteration : 5, Variation : 0.11244669193274526, EigenVal : 167.11596710554994
# Best mac match (fast solver) : 0.4637242358884118
# Iteration : 6, Variation : 0.09436162191204633, EigenVal : 166.79082909258565
# Best mac match (fast solver) : 0.4751700051867846
# ...

# %%
analyse_mesh('Results/_topopt_cache/TOM_2022-03-28_09_23_09.vtk', 
             'eigen_values_lcar05_T11_2022-03-28_09_25_04.npy', 'T11')
